# %%
# !pip install pandas

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\HP\Downloads\Basic stats - 1\sales_data_with_discounts.csv")
df.head(50)
# Out:
#           Date       Day  SKU City  Volume         BU    Brand  \
# 0   01-04-2021  Thursday  M01    C      15    Mobiles    RealU
# 1   01-04-2021  Thursday  M02    C      10    Mobiles    RealU
# 2   01-04-2021  Thursday  M03    C       7    Mobiles     YouM
# 3   01-04-2021  Thursday  M04    C       6    Mobiles     YouM
# 4   01-04-2021  Thursday  M05    C       3    Mobiles     YouM
# 5   01-04-2021  Thursday  M06    C       3    Mobiles    RealU
# 6   01-04-2021  Thursday  M07    C       3    Mobiles  Sumsang
# 7   01-04-2021  Thursday  M08    C       2    Mobiles  Sumsang
# 8   01-04-2021  Thursday  M09    C       2    Mobiles   Orange
# 9   01-04-2021  Thursday  M10    C       3    Mobiles   Orange
# 10  01-04-2021  Thursday  F01    C      13       FMCG   Babaji
# 11  01-04-2021  Thursday  F02    C       4       FMCG    Vedic
# 12  01-04-2021  Thursday  F03    C       4       FMCG    Vedic
# 13  01-04-2021  Thursday  F04    C       9       FMCG   Babaji
# ...

# %%
df_numeric=df.select_dtypes(include="number")
df_numeric
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        15      12100             181500          11.654820     21153.498820
# 1        10      10100             101000          11.560498     11676.102961
# 2         7      16100             112700           9.456886     10657.910157
# 3         6      20100             120600           6.935385      8364.074702
# 4         3       8100              24300          17.995663      4372.946230
# ..      ...        ...                ...                ...              ...
# 445       2       1300               2600          15.475687       402.367873
# 446       6       2600              15600          17.057027      2660.896242
# 447       2       1600               3200          18.965550       606.897606
# 448       3       1900               5700          16.793014       957.201826
# 449       1       3100               3100          15.333300       475.332295
#
#      Net Sales Value
# ...

# %%
df_numeric.mean()
# Out:
# Volume                   5.066667
# Avg Price            10453.433333
# Total Sales Value    33812.835556
# Discount Rate (%)       15.155242
# Discount Amount       3346.499424
# Net Sales Value      30466.336131
# dtype: float64

# %%
df_numeric.median()
# Out:
# Volume                  4.000000
# Avg Price            1450.000000
# Total Sales Value    5700.000000
# Discount Rate (%)      16.577766
# Discount Amount       988.933733
# Net Sales Value      4677.788059
# dtype: float64

# %%
df_numeric.mode()
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0       3.0      400.0            24300.0           5.007822        69.177942
# 1       NaN      450.0                NaN           5.055218        73.025199
# 2       NaN      500.0                NaN           5.059801        93.649161
# 3       NaN     1300.0                NaN           5.072124        94.682735
# 4       NaN     8100.0                NaN           5.084108       102.705757
# ..      ...        ...                ...                ...              ...
# 445     NaN        NaN                NaN          19.940610     17900.983733
# 446     NaN        NaN                NaN          19.965340     21153.498820
# 447     NaN        NaN                NaN          19.976879     21496.675367
# 448     NaN        NaN                NaN          19.982257     25328.224204
# 449     NaN        NaN                NaN          19.992407     25738.022194
#
#      Net Sales Value
# ...

# %%
df_numeric.std()
# Out:
# Volume                   4.231602
# Avg Price            18079.904840
# Total Sales Value    50535.074173
# Discount Rate (%)        4.220602
# Discount Amount       4509.902963
# Net Sales Value      46358.656624
# dtype: float64

# %%
import matplotlib.pyplot as plt
plt.hist(df_numeric['Volume'].dropna(),bins=20,edgecolor='black')
plt.title('Volume distribution')
plt.xlabel('Volume')
plt.ylabel('Count')
plt.show()

# %%
plt.hist(df_numeric['Avg Price'].dropna(),bins=20,edgecolor='black')
plt.title('Avg Price distribution')
plt.xlabel('Avg Price')
plt.ylabel('Count')
plt.show()

# %%
plt.hist(df_numeric['Total Sales Value'].dropna(),bins=20,edgecolor='black')
plt.title('Total Sales Value distribution')
plt.xlabel('Total Sales Value')
plt.ylabel('Count')
plt.show()

# %%
plt.hist(df_numeric['Discount Rate (%)'].dropna(),bins=20,edgecolor='black')
plt.title('Discount Rate (%) distribution')
plt.xlabel('Discount Rate (%) Value')
plt.ylabel('Count')
plt.show()

# %%
plt.hist(df_numeric['Discount Amount'].dropna(),bins=20,edgecolor='black')
plt.title('Discount Amount distribution')
plt.xlabel('Discount Amount')
plt.ylabel('Count')
plt.show()

# %%
plt.hist(df_numeric['Net Sales Value'].dropna(),bins=20,edgecolor='black')
plt.title('Net Sales Value distribution')
plt.xlabel('Net Sales Value')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8,10))
plt.boxplot(df_numeric['Volume'].dropna(),patch_artist=True)
plt.xlabel('Volume')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8,10))
plt.boxplot(df_numeric['Avg Price'].dropna(),patch_artist=True)
plt.xlabel('Avg Price')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.boxplot(df_numeric['Total Sales Value'].dropna(),patch_artist=True)
plt.xlabel('Total Sales Value')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.boxplot(df_numeric['Discount Rate (%)'].dropna(),patch_artist=True)
plt.xlabel('Discount Rate (%)')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.boxplot(df_numeric['Discount Amount'].dropna(),patch_artist=True)
plt.xlabel('Discount Amount')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.boxplot(df_numeric['Net Sales Value'].dropna(),patch_artist=True)
plt.xlabel('Net Sales Value')
plt.ylabel('Count')
plt.show()

# %%
df_categorical=df.select_dtypes(include="object")
df_categorical
# Out:
#            Date       Day  SKU City         BU  Brand       Model
# 0    01-04-2021  Thursday  M01    C    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C  Lifestyle  Jeera     M-Shoes
#
# [450 rows x 7 columns]

# %%
df_categorical_date=df_categorical['Date'].value_counts()
print(df_categorical_date)
plt.barh(df_categorical_date.index,df_categorical_date.values,color=["blue"])
plt.xlabel("Count")
plt.ylabel("Date")
plt.show()
# Out:
# Date
# 01-04-2021    30
# 02-04-2021    30
# 03-04-2021    30
# 04-04-2021    30
# 05-04-2021    30
# 06-04-2021    30
# 07-04-2021    30
# 08-04-2021    30
# 09-04-2021    30
# 10-04-2021    30
# 11-04-2021    30
# 12-04-2021    30
# 13-04-2021    30
# 14-04-2021    30
# 15-04-2021    30
# Name: count, dtype: int64

# %%
df_categorical_day=df_categorical['Day'].value_counts()
print(df_categorical_day)
plt.barh(df_categorical_day.index,df_categorical_day.values,color=["yellow"])
plt.xlabel("Count")
plt.ylabel("Day")
plt.show()
# Out:
# Day
# Thursday     90
# Friday       60
# Saturday     60
# Sunday       60
# Monday       60
# Tuesday      60
# Wednesday    60
# Name: count, dtype: int64

# %%
df_categorical_day=df_categorical['SKU'].value_counts()
print(df_categorical_day)
plt.barh(df_categorical_day.index,df_categorical_day.values,color=["violet"])
plt.xlabel("Count")
plt.ylabel("SKU")
plt.show()
# Out:
# SKU
# M01    15
# M02    15
# M03    15
# M04    15
# M05    15
# M06    15
# M07    15
# M08    15
# M09    15
# M10    15
# F01    15
# F02    15
# F03    15
# F04    15
# F05    15
# F06    15
# F07    15
# F08    15
# F09    15
# F10    15
# L01    15
# L02    15
# L03    15
# L04    15
# L05    15
# L06    15
# L07    15
# L08    15
# L09    15
# L10    15
# Name: count, dtype: int64

# %%
df_categorical_day=df_categorical['City'].value_counts()
print(df_categorical_day)
plt.bar(df_categorical_day.index,df_categorical_day.values,color=["pink"])
plt.xlabel("City")
plt.ylabel("Count")
plt.show()
# Out:
# City
# C    450
# Name: count, dtype: int64

# %%
df_categorical_day=df_categorical['BU'].value_counts()
print(df_categorical_day)
plt.bar(df_categorical_day.index,df_categorical_day.values,color=["green"])
plt.xlabel("BU")
plt.ylabel("Count")
plt.show()
# Out:
# BU
# Mobiles      150
# FMCG         150
# Lifestyle    150
# Name: count, dtype: int64

# %%
df_categorical_day=df_categorical['Brand'].value_counts()
print(df_categorical_day)
plt.barh(df_categorical_day.index,df_categorical_day.values,color=["orange"])
plt.xlabel("Count")
plt.ylabel("Brand")
plt.show()
# Out:
# Brand
# Jeera      90
# Viva       60
# Gear       60
# RealU      45
# YouM       45
# Babaji     45
# Vedic      45
# Orange     30
# Sumsang    30
# Name: count, dtype: int64

# %%
df_categorical_day=df_categorical['Model'].value_counts()
print(df_categorical_day)
plt.barh(df_categorical_day.index,df_categorical_day.values,color=["orange"])
plt.xlabel("Count")
plt.ylabel("Model")
plt.show()
# Out:
# Model
# RU-10             15
# RU-9 Plus         15
# YM-99             15
# YM-99 Plus        15
# YM-98             15
# RU-9              15
# S-20              15
# S-21              15
# O-10              15
# O-11              15
# Babaji Oil        15
# Vedic Cream       15
# Vedic Shampoo     15
# Babaji Shampoo    15
# Babaji Cream      15
# Vedic Oil         15
# Gear Oil          15
# Gear Cream        15
# Gear Shampoo      15
# Gear BB Cream     15
# M- T Shirts       15
# M- Inners         15
# W-Casuals         15
# W-Inners          15
# M-Jeans           15
# M-Casuals         15
# W-Western         15
# W-Lounge          15
# M-Formals         15
# M-Shoes           15
# Name: count, dtype: int64

# %%
import seaborn as sns
n=len(df_numeric.columns)
n
# Out:
# 6

# %%
for i in range(0,n):
    #print(df_numeric.columns[i])
    plt.figure(figsize=(8, 4))
    sns.histplot(df_numeric[df_numeric.columns[i]],kde=True)
    plt.show()

# %%
#mean_vol=df['Volume'].mean()
#print(mean_vol)
#std_vol=df['Volume'].std()
#print(std_vol)
#df['z_score']=df['Volume']-

# %%
#df['z_score_vol']=(df['Volume']-mean_vol)/std_vol
#df.head()

# %%
##df[(df.z_score_vol<-3)|(df.z_score_vol>3)]

# %%
##df_no_outliers_vol=df[(df.z_score_vol>-3)&(df.z_score_vol<3)]
##df_no_outliers_vol

# %%
n=len(df_numeric.columns)
n

for i in range(0,n):
    #print(df_numeric.columns[i])
    mean=df_numeric[df_numeric.columns[i]].mean()
    std=df_numeric[df_numeric.columns[i]].std()
    z_score=(df_numeric[df_numeric.columns[i]]-mean)/std
    
    plt.figure(figsize=(8, 4))
    sns.histplot(z_score,kde=True)
    plt.show()

# %%
pd_encoded=pd.get_dummies(df.select_dtypes(include='object'))
pd_encoded.head()
# Out:
#    Date_01-04-2021  Date_02-04-2021  Date_03-04-2021  Date_04-04-2021  \
# 0             True            False            False            False
# 1             True            False            False            False
# 2             True            False            False            False
# 3             True            False            False            False
# 4             True            False            False            False
#
#    Date_05-04-2021  Date_06-04-2021  Date_07-04-2021  Date_08-04-2021  \
# 0            False            False            False            False
# 1            False            False            False            False
# 2            False            False            False            False
# 3            False            False            False            False
# 4            False            False            False            False
#
#    Date_09-04-2021  Date_10-04-2021  ...  Model_Vedic Cream  Model_Vedic Oil  \
# ...
